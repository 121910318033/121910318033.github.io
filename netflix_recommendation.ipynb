# %% [markdown]
# <a href="https://colab.research.google.com/github/121910318033/121910318033.github.io/blob/main/netflix_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=f288cc55eea31caa28bc7fb9f980185dd807047b9b215bf210d9cc892043aabe
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('netflix_recommendation.csv', header = None)
transactions=[]
for i in range(0,7466):
  transactions.append([str(dataset.values[i,j]) for j in range(0,20)])

# %%
from apyori import apriori
basket_intelligence =apriori(transactions= transactions, min_support=0.003, min_confidence =0.2,min_lift=3,min_length=2)

# %%
results =list(basket_intelligence)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'Black Panther', 'Captain America'}), support=0.00334851326011251, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.24509803921568626, lift=5.140174047146949)]),
#  RelationRecord(items=frozenset({'Game of thrones', 'Comedy nights with Kapil'}), support=0.0032145727297080095, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'Comedy nights with Kapil'}), confidence=0.20512820512820512, lift=3.1001764766946955)]),
#  RelationRecord(items=frozenset({'Kanan Gill Comedy', 'Comedy nights with Kapil'}), support=0.008036431824270024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kanan Gill Comedy'}), items_add=frozenset({'Comedy nights with Kapil'}), confidence=0.2714932126696833, lift=4.103174748566509)]),
# ...

# %%
def inspect(results):
  lhs  = [tuple(result[2][0][0])[0] for result in results]
  rhs  = [tuple(result[2][0][1])[0] for result in results]
  supports   =[result[1] for result in results]
  return list(zip(lhs,rhs,supports))
resultsinDataFrame = pd.DataFrame(inspect(results), columns =['Movie 1','Movie 2', 'support'])

# %%
resultsinDataFrame
# Out:
#                       Movie 1                   Movie 2   support
# 0             Captain America             Black Panther  0.003349
# 1             Game of thrones  Comedy nights with Kapil  0.003215
# 2           Kanan Gill Comedy  Comedy nights with Kapil  0.008036
# 3             Game of thrones             Prision Break  0.004554
# 4              Harry Potter 1            Harry Potter 2  0.005759
# ..                        ...                       ...       ...
# 154                 inception  The Silence of the Lambs  0.004018
# 155             The Lion King                       nan  0.003349
# 156             The Lion King                       nan  0.003081
# 157  The Silence of the Lambs     The Lord of the rings  0.003482
# 158                 inception                       nan  0.003081
#
# [159 rows x 3 columns]

# %%
resultsinDataFrame.nlargest(n=10,columns='support')
# Out:
#                                                Movie 1  \
# 7                                         Interstellar
# 48                                        Interstellar
# 20   The Lord of the Rings: The Fellowship of the Ring
# 92   The Lord of the Rings: The Fellowship of the Ring
# 2                                    Kanan Gill Comedy
# 26                                   Kanan Gill Comedy
# 15                               The Lord of the rings
# 31                                    The Intouchables
# 82                               The Lord of the rings
# 103                                   The Intouchables
#
#                       Movie 2   support
# 7                   inception  0.015939
# 48                  inception  0.015939
# 20                  inception  0.008706
# 92                  inception  0.008706
# 2    Comedy nights with Kapil  0.008036
# 26   Comedy nights with Kapil  0.008036
# 15                      Billa  0.007233
# ...
